# %%
# %sql
select * from bronze.metadata.bronze_config
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_name</th><th>dataset_name</th><th>source_path</th><th>file_pattern</th><th>target_table</th><th>delimiter</th><th>header_flag</th><th>is_active</th><th>created_timestamp</th></tr></thead><tbody><tr><td>netflix</td><td>netflix_tv_shows_detailed</td><td>/Volumes/bronze/metadata/landing_files/*/</td><td>netflix_tv_shows_detailed_up_to_2025 .csv</td><td>bronze.netflix.netflix_tv_shows_detailed</td><td>,</td><td>true</td><td>true</td><td>2026-06-07T04:46:31.356Z</td></tr><tr><td>netflix</td><td>netflix_titles</td><td>/Volumes/bronze/metadata/landing_files/*/</td><td>netflix_titles.csv</td><td>bronze.netflix.netflix_titles</td><td>,</td><td>true</td><td>true</td><td>2026-06-07T04:46:31.356Z</td></tr><tr><td>netflix</td><td>netflix_reviews</td><td>/Volumes/bronze/metadata/landing_files/*/</td><td>netflix_reviews.csv</td><td>bronze.netflix.netflix_reviews</td><td>,</td><td>true</td><td>true</td><td>2026-06-07T04:46:31.356Z</td></tr><tr><td>netflix</td><td>netflix_movies</td><td>/Volumes/bronze/metadata/landing_files/*/</td><td>netflix_movies.csv</td><td>bronze.netflix.netflix_movies</td><td>,</td><td>true</td><td>true</td><td>2026-06-07T04:46:31.356Z</td></tr><tr><td>netflix</td><td>netflix_stock_history</td><td>/Volumes/bronze/metadata/landing_files/*/</td><td>Netflix_stock_history.csv</td><td>bronze.netflix.netflix_stock_history</td><td>,</td><td>true</td><td>true</td><td>2026-06-07T04:46:31.356Z</td></tr><tr><td>netflix</td><td>netflix_tv_shows_movies</td><td>/Volumes/bronze/metadata/landing_files/*/</td><td>Netflix TV Shows and Movies.csv</td><td>bronze.netflix.netflix_tv_shows_movies</td><td>,</td><td>true</td><td>true</td><td>2026-06-07T04:46:31.356Z</td></tr></tbody></table></div>

# %%
# %sql
select * from bronze.metadata.bronze_audit_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_id</th><th>source_name</th><th>dataset_name</th><th>target_table</th><th>status</th><th>start_time</th><th>end_time</th><th>error_message</th></tr></thead><tbody><tr><td>5e40003d-e53d-4c65-acfd-9c53592a76a5</td><td>netflix</td><td>netflix_movies</td><td>bronze.netflix.netflix_movies</td><td>FAILED</td><td>2026-06-07T05:29:23.470Z</td><td>2026-06-07T05:29:32.455Z</td><td>Traceback (most recent call last):
#   File "/home/spark-00ebdbac-0718-4116-be64-e0/.ipykernel/2043/command-4620305497995246-1539997828", line 86, in <module>
#     query.awaitTermination()
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/streaming/query.py", line 100, in awaitTermination
#     self._execute_streaming_query_cmd(cmd)
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/streaming/query.py", line 188, in _execute_streaming_query_cmd
#     (_, properties, _) = self._session.client.execute_command(exec_cmd)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py", line 1538, in execute_command
#     data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
#                                                      ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py", line 2086, in _execute_and_fetch
#     for response in self._execute_and_fetch_as_iterator(
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py", line 2062, in _execute_and_fetch_as_iterator
#     self._handle_error(error)
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py", line 2380, in _handle_error
#     self._handle_rpc_error(error)
#   File "/databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py", line 2458, in _handle_rpc_error
#     raise convert_exception(
# pyspark.errors.exceptions.connect.StreamingQueryException: [STREAM_FAILED] Query [id = de175af8-cacc-49a8-ba2a-b7d9c86f5d5a, runId = 2d205b75-5881-43dd-9a93-2272d3ddfc26] terminated with exception: Datasource with partition do not allow recursive file loading. SQLSTATE: XXKST
# === Streaming Query ===
# Identifier: [id = de175af8-cacc-49a8-ba2a-b7d9c86f5d5a, runId = 2d205b75-5881-43dd-9a93-2272d3ddfc26]
# Current Start Offsets: {CloudFilesSource[/Volumes/bronze/metadata/landing_files/]: {"seqNum":3,"sourceVersion":3,"lastBackfillStartTimeMs":1780810168926,"lastBackfillFinishTimeMs":1780810170570,"lastInputPath":"/Volumes/bronze/metadata/landing_files/"}}
# Current End Offsets: {CloudFilesSource[/Volumes/bronze/metadata/landing_files/]: {"seqNum":3,"sourceVersion":3,"lastBackfillStartTimeMs":1780810168926,"lastBackfillFinishTimeMs":1780810170570,"lastInputPath":"/Volumes/bronze/metadata/landing_files/"}}
#
# Current State: ACTIVE
# Thread State: RUNNABLE
#
# Logical Plan:
# ~WriteToMicroBatchDataSourceV1 `bronze`.`netflix`.`netflix_movies`, DeltaSink[abfss://databricksmetastore@vjweustg01.dfs.core.windows.net/__unitystorage/catalogs/20abc93c-23fa-439e-b483-0663542c6830/tables/92741466-0e8e-4be5-8399-0b8ed8c0b797], de175af8-cacc-49a8-ba2a-b7d9c86f5d5a, [checkpointLocation=/Volumes/bronze/metadata/bronze_checkpoints/netflix/netflix_movies, mergeSchema=true, path=abfss://databricksmetastore@vjweustg01.dfs.core.windows.net/__unitystorage/catalogs/20abc93c-23fa-439e-b483-0663542c6830/tables/92741466-0e8e-4be5-8399-0b8ed8c0b797], Append
# +- ~Project [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, _source_name#21113, _dataset_name#21115, _source_file_name#21117, _ingestion_timestamp#21121, _ingestion_date#21123, 5e40003d-e53d-4c65-acfd-9c53592a76a5 AS _run_id#21125]
#    +- ~Project [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, _source_name#21113, _dataset_name#21115, _source_file_name#21117, _ingestion_timestamp#21121, current_date(Some(Etc/UTC)) AS _ingestion_date#21123]
#       +- ~Project [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, _source_name#21113, _dataset_name#21115, _source_file_name#21117, current_timestamp() AS _ingestion_timestamp#21121]
#          +- ~Project [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, _source_name#21113, _dataset_name#21115, _metadata#21112.file_path AS _source_file_name#21117]
#             +- ~Project [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, _source_name#21113, netflix_movies AS _dataset_name#21115, _metadata#21112]
#                +- ~Project [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, netflix AS _source_name#21113, _metadata#21112]
#                   +- ~StreamingExecutionRelation CloudFilesSource[/Volumes/bronze/metadata/landing_files/], [title#21100, year#21101, certificate#21102, duration#21103, genre#21104, rating#21105, description#21106, stars#21107, votes#21108, ingest_dt#21109, _rescued_data#21110, _metadata#21112], name=<Unassigned>
#
#
# Physical Plan:
# PhotonResultStage
# +- PhotonColumnarToRow
#    +- PhotonProject [title#21179, year#21180, certificate#21181, duration#21182, genre#21183, rating#21184, description#21185, stars#21186, votes#21187, ingest_dt#21188, _rescued_data#21189, netflix AS _source_name#21113, netflix_movies AS _dataset_name#21115, _metadata#21190.file_path AS _source_file_name#21117, 2026-06-07 05:29:30.623 AS _ingestion_timestamp#21121, 2026-06-07 AS _ingestion_date#21123, 5e40003d-e53d-4c65-acfd-9c53592a76a5 AS _run_id#21125]
#       +- PhotonProject [title#21179, year#21180, certificate#21181, duration#21182, genre#21183, rating#21184, description#21185, stars#21186, votes#21187, _rescued_data#21189, ingest_dt#21188, knownnotnull(named_struct(file_path, file_path#21204)) AS _metadata#21190]
#          +- PhotonRowToColumnar
#             +- FileScan csv [title#21179,year#21180,certificate#21181,duration#21182,genre#21183,rating#21184,description#21185,stars#21186,votes#21187,_rescued_data#21189,ingest_dt#21188,file_path#21204] Batched: false, DataFilters: [], Format: CSV, Location: CloudFilesSourceFileIndex(1 paths)[dbfs:/Volumes/bronze/metadata/landing_files], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<title:string,year:string,certificate:string,duration:string,genre:string,rating:string,des...
#
#
# JVM stacktrace:
# org.apache.spark.sql.streaming.StreamingQueryException
# 	at org.apache.spark.sql.execution.streaming.runtime.StreamExecution.$anonfun$runStream$1(StreamExecution.scala:620)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:146)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:349)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:345)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(A

# %%
# %sql
select * from bronze.metadata.bronze_audit_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_id</th><th>source_name</th><th>dataset_name</th><th>target_table</th><th>status</th><th>event_time</th><th>error_message</th></tr></thead><tbody><tr><td>aa268928-cb3a-43a2-b744-1359eb15427a</td><td>netflix</td><td>netflix_tv_shows_detailed</td><td>bronze.netflix.netflix_tv_shows_detailed</td><td>SUCCESS</td><td>2026-06-27T13:49:33.317Z</td><td>null</td></tr><tr><td>aa268928-cb3a-43a2-b744-1359eb15427a</td><td>netflix</td><td>netflix_tv_shows_detailed</td><td>bronze.netflix.netflix_tv_shows_detailed</td><td>STARTED</td><td>2026-06-27T13:49:27.026Z</td><td>null</td></tr><tr><td>060382d5-854c-45bf-ac4c-c3b4b5ba4ec8</td><td>netflix</td><td>netflix_tv_shows_movies</td><td>bronze.netflix.netflix_tv_shows_movies</td><td>SUCCESS</td><td>2026-06-27T13:50:23.290Z</td><td>null</td></tr><tr><td>022c9e5b-3585-4f57-91fd-528e62147dd5</td><td>netflix</td><td>netflix_tv_shows_movies</td><td>bronze.netflix.netflix_tv_shows_movies</td><td>SUCCESS</td><td>2026-06-27T13:49:34.875Z</td><td>null</td></tr><tr><td>060382d5-854c-45bf-ac4c-c3b4b5ba4ec8</td><td>netflix</td><td>netflix_tv_shows_movies</td><td>bronze.netflix.netflix_tv_shows_movies</td><td>STARTED</td><td>2026-06-27T13:50:18.611Z</td><td>null</td></tr><tr><td>022c9e5b-3585-4f57-91fd-528e62147dd5</td><td>netflix</td><td>netflix_tv_shows_movies</td><td>bronze.netflix.netflix_tv_shows_movies</td><td>STARTED</td><td>2026-06-27T13:49:28.889Z</td><td>null</td></tr><tr><td>b6a727ce-472d-4f63-ac7f-2a05e5a891a7</td><td>netflix</td><td>netflix_stock_history</td><td>bronze.netflix.netflix_stock_history</td><td>SUCCESS</td><td>2026-06-27T13:50:13.646Z</td><td>null</td></tr><tr><td>b6a727ce-472d-4f63-ac7f-2a05e5a891a7</td><td>netflix</td><td>netflix_stock_history</td><td>bronze.netflix.netflix_stock_history</td><td>STARTED</td><td>2026-06-27T13:50:09.334Z</td><td>null</td></tr><tr><td>579805d9-9cc7-4499-8f57-bebd1322fd27</td><td>netflix</td><td>netflix_stock_history</td><td>bronze.netflix.netflix_stock_history</td><td>SUCCESS</td><td>2026-06-27T13:49:30.821Z</td><td>null</td></tr><tr><td>579805d9-9cc7-4499-8f57-bebd1322fd27</td><td>netflix</td><td>netflix_stock_history</td><td>bronze.netflix.netflix_stock_history</td><td>STARTED</td><td>2026-06-27T13:49:23.958Z</td><td>null</td></tr><tr><td>252d47e0-290d-4ea5-9000-d72e624db444</td><td>netflix</td><td>netflix_reviews</td><td>bronze.netflix.netflix_reviews</td><td>SUCCESS</td><td>2026-06-27T13:49:26.836Z</td><td>null</td></tr><tr><td>2d7aa57b-2760-428b-951e-c33ac2e2b284</td><td>netflix</td><td>netflix_reviews</td><td>bronze.netflix.netflix_reviews</td><td>SUCCESS</td><td>2026-06-27T13:50:19.186Z</td><td>null</td></tr><tr><td>2d7aa57b-2760-428b-951e-c33ac2e2b284</td><td>netflix</td><td>netflix_reviews</td><td>bronze.netflix.netflix_reviews</td><td>STARTED</td><td>2026-06-27T13:50:15.065Z</td><td>null</td></tr><tr><td>252d47e0-290d-4ea5-9000-d72e624db444</td><td>netflix</td><td>netflix_reviews</td><td>bronze.netflix.netflix_reviews</td><td>STARTED</td><td>2026-06-27T13:49:20.234Z</td><td>null</td></tr><tr><td>29b32559-bb60-405b-99cd-35208ca79006</td><td>netflix</td><td>netflix_movies</td><td>bronze.netflix.netflix_movies</td><td>SUCCESS</td><td>2026-06-27T13:49:22.731Z</td><td>null</td></tr><tr><td>29b32559-bb60-405b-99cd-35208ca79006</td><td>netflix</td><td>netflix_movies</td><td>bronze.netflix.netflix_movies</td><td>STARTED</td><td>2026-06-27T13:49:13.029Z</td><td>null</td></tr><tr><td>a7853745-280f-4f77-a448-67d483cc036a</td><td>netflix</td><td>netflix_titles</td><td>bronze.netflix.netflix_titles</td><td>SUCCESS</td><td>2026-06-27T13:50:11.965Z</td><td>null</td></tr><tr><td>e2365fa2-06c7-44a2-9c7d-e3915cb2988e</td><td>netflix</td><td>netflix_movies</td><td>bronze.netflix.netflix_movies</td><td>SUCCESS</td><td>2026-06-27T13:49:59.849Z</td><td>null</td></tr><tr><td>1e0cf2cc-d79d-4bae-a5bd-73feae670260</td><td>netflix</td><td>netflix_t ...

# %%
# %sql
DROP TABLE IF EXISTS bronze.metadata.bronze_audit_log;

CREATE TABLE bronze.metadata.bronze_audit_log
(
  run_id STRING,
  source_name STRING,
  dataset_name STRING,
  target_table STRING,
  status STRING,
  event_time TIMESTAMP,
  error_message STRING
);

# %%
spark.sql(f"""
    INSERT INTO bronze.metadata.bronze_audit_log
    VALUES
    (
      '{run_id}',
      '{source_name}',
      '{dataset_name}',
      '{target_table}',
      'STARTED',
      current_timestamp(),
      NULL
    )
""")

# %%
spark.sql(f"""
    INSERT INTO bronze.metadata.bronze_audit_log
    VALUES
    (
      '{run_id}',
      '{source_name}',
      '{dataset_name}',
      '{target_table}',
      'SUCCESS',
      current_timestamp(),
      NULL
    )
""")

# %%
spark.sql(f"""
    INSERT INTO bronze.metadata.bronze_audit_log
    VALUES
    (
      '{run_id}',
      '{source_name}',
      '{dataset_name}',
      '{target_table}',
      'FAILED',
      current_timestamp(),
      '{error_message}'
    )
""")

# %%
from pyspark.sql.functions import (
    current_timestamp,
    current_date,
    lit,
    col
)

import uuid
import traceback
import re


# ------------------------------------------------------------
# 1. Notebook Parameters
# ------------------------------------------------------------

dbutils.widgets.text("source_name", "netflix")
dbutils.widgets.text("dataset_name", "netflix_movies")

source_name = dbutils.widgets.get("source_name")
dataset_name = dbutils.widgets.get("dataset_name")
run_id = str(uuid.uuid4())


# ------------------------------------------------------------
# 2. Clean column name function
# ------------------------------------------------------------

def clean_column_name(column_name):
    cleaned = column_name.strip().lower()
    cleaned = re.sub(r"[ ,;{}()\n\t=]+", "_", cleaned)
    cleaned = re.sub(r"_+", "_", cleaned)
    cleaned = cleaned.strip("_")
    return cleaned


try:
    # ------------------------------------------------------------
    # 3. Read metadata config
    # ------------------------------------------------------------

    config_df = spark.sql(f"""
        SELECT *
        FROM bronze.metadata.bronze_config
        WHERE source_name = '{source_name}'
          AND dataset_name = '{dataset_name}'
          AND is_active = true
    """)

    if config_df.count() == 0:
        raise Exception(f"No active config found for {source_name}.{dataset_name}")

    config = config_df.collect()[0]

    source_path = config["source_path"]
    file_pattern = config["file_pattern"]
    target_table = config["target_table"]
    delimiter = config["delimiter"]
    header_flag = config["header_flag"]

    schema_path = f"/Volumes/bronze/metadata/bronze_schemas/{source_name}/{dataset_name}"
    checkpoint_path = f"/Volumes/bronze/metadata/bronze_checkpoints/{source_name}/{dataset_name}"


    # ------------------------------------------------------------
    # 4. Insert audit STARTED - append only
    # ------------------------------------------------------------

    spark.sql(f"""
        INSERT INTO bronze.metadata.bronze_audit_log
        VALUES
        (
          '{run_id}',
          '{source_name}',
          '{dataset_name}',
          '{target_table}',
          'STARTED',
          current_timestamp(),
          NULL
        )
    """)


    # ------------------------------------------------------------
    # 5. Read CSV incrementally using Auto Loader
    # ------------------------------------------------------------

    raw_df = (
        spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("cloudFiles.schemaLocation", schema_path)
        .option("cloudFiles.schemaEvolutionMode", "rescue")
        .option("rescuedDataColumn", "_rescued_data")
        .option("header", header_flag)
        .option("delimiter", delimiter)
        .option("inferColumnTypes", "false")
        .option("pathGlobFilter", file_pattern)
        .load(source_path)
    )


    # ------------------------------------------------------------
    # 6. Clean invalid Delta column names
    # ------------------------------------------------------------

    cleaned_columns = [
        col(column_name).alias(clean_column_name(column_name))
        for column_name in raw_df.columns
        if column_name != "_rescued_data"
    ]

    if "_rescued_data" in raw_df.columns:
        df = raw_df.select(
            *cleaned_columns,
            col("_rescued_data")
        )
    else:
        df = raw_df.select(*cleaned_columns)


    # ------------------------------------------------------------
    # 7. Add Bronze audit columns
    # ------------------------------------------------------------

    df = (
        df
        .withColumn("_source_name", lit(source_name))
        .withColumn("_dataset_name", lit(dataset_name))
        .withColumn("_source_file_path", col("_metadata.file_path"))
        .withColumn("_ingestion_timestamp", current_timestamp())
        .withColumn("_ingestion_date", current_date())
        .withColumn("_run_id", lit(run_id))
    )


    # ------------------------------------------------------------
    # 8. Write to Bronze Delta table
    # ------------------------------------------------------------

    query = (
        df.writeStream
        .format("delta")
        .option("checkpointLocation", checkpoint_path)
        .option("mergeSchema", "true")
        .trigger(availableNow=True)
        .toTable(target_table)
    )

    query.awaitTermination()


    # ------------------------------------------------------------
    # 9. Insert audit SUCCESS - append only
    # ------------------------------------------------------------

    spark.sql(f"""
        INSERT INTO bronze.metadata.bronze_audit_log
        VALUES
        (
          '{run_id}',
          '{source_name}',
          '{dataset_name}',
          '{target_table}',
          'SUCCESS',
          current_timestamp(),
          NULL
        )
    """)


except Exception as e:
    # ------------------------------------------------------------
    # 10. Insert audit FAILED - append only
    # ------------------------------------------------------------

    error_message = traceback.format_exc().replace("'", "''")

    spark.sql(f"""
        INSERT INTO bronze.metadata.bronze_audit_log
        VALUES
        (
          '{run_id}',
          '{source_name}',
          '{dataset_name}',
          '{target_table}',
          'FAILED',
          current_timestamp(),
          '{error_message}'
        )
    """)

    raise e

# %%
# %sql
UPDATE bronze.metadata.bronze_config
SET source_path = '/Volumes/bronze/metadata/landing_files/*/'
WHERE source_name = 'netflix';

# %%
# %sql
UPDATE bronze.metadata.bronze_config
SET file_pattern = 'Netflix TV Shows and Movies.csv'
WHERE dataset_name = 'netflix_tv_shows_movies';

UPDATE bronze.metadata.bronze_config
SET file_pattern = 'Netflix_stock_history.csv'
WHERE dataset_name = 'netflix_stock_history';

UPDATE bronze.metadata.bronze_config
SET file_pattern = 'netflix_movies.csv'
WHERE dataset_name = 'netflix_movies';

UPDATE bronze.metadata.bronze_config
SET file_pattern = 'netflix_reviews.csv'
WHERE dataset_name = 'netflix_reviews';

UPDATE bronze.metadata.bronze_config
SET file_pattern = 'netflix_titles.csv'
WHERE dataset_name = 'netflix_titles';

UPDATE bronze.metadata.bronze_config
SET file_pattern = 'netflix_tv_shows_detailed_up_to_2025 .csv'
WHERE dataset_name = 'netflix_tv_shows_detailed';

# %%
# %sql
SELECT source_name, dataset_name, source_path, file_pattern, target_table
FROM bronze.metadata.bronze_config
WHERE source_name = 'netflix'
ORDER BY dataset_name;

# %%
' /Volumes/bronze/metadata/landing_files/*/'
